# %% [markdown]
# # ggplot Presentation

# %% [markdown]
# ## Einführung

# %% [markdown]
# ## Beispiele

# %%
library(ggplot2)
library(car)
data("mtcars")
plot(x = mtcars$hp, y = mtcars$mpg)
# Out:
# plot without title
